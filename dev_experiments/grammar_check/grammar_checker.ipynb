# %%
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import cohere
from cohere.classify import Example
apiKey = ''
co = cohere.Client(apiKey)

# %%
def gen_grammar_check(query):
    query = query.lower()
    response = co.generate(
    model='xlarge',
    prompt=f'This is a spell check generator that checks for grammar and corrects it. This also capitalizes the first letter of the sentence.\n\nSample: I would like a peice of pie.\nCorrect: I would like a piece of the pie.\n\nSample: my coworker said he used a financial planner to help choose his stocks so he wouldn\'t loose money.\nCorrect: My coworker said he used a financial planner to help him choose his stocks so he wouldn\'t lose money.\n\nSample: I ordered pizza, I also ordered garlic knots.\nCorrect: I ordered pizza; I also ordered garlic knots.\n\nSample: i bought winning lottery ticket the corner store\nCorrect: I bought my winning lottery ticket at the corner store.\n\nSample: try to reread your work to ensure you haven\'t left out any small words\nCorrect: Try to reread your work to ensure you haven\'t left out any small words.\n\nSample: I went to the movies with my sister. We will see the new comedy about dancing dogs.\nCorrect: I went to the movies with my sister. We saw the new comedy about dancing dogs.\n\nSample: the boy took their turn on the field.\nCorrect: The boy took his turn on the field.\n--\nSample: I could of won the race if I trained more.\nCorrect: I could have won the race if I had trained more.\n--\nSample: I went to the office, than i started my meeting.\nCorrect: I went to the office, then I started my meeting.\n--\nSample: {query}\nCorrect:',
    max_tokens=100,
    temperature=1.2,
    k=0,
    p=0.75,
    frequency_penalty=0,
    presence_penalty=0,
    stop_sequences=["--"],
    return_likelihoods='NONE')

    output = response.generations[0].text.rstrip("(\n)--")
    output = output.lstrip(" ")
    output = output.lower()
    
    embeds = co.embed(texts=[query, output],
                  model='large',
                  truncate='LEFT').embeddings
    similarity_value = cosine_similarity(X=[embeds[0]], Y=[embeds[1]], dense_output=True)
    print(f"input query: {query}")
    print(f"generated correction: {output}")
    print(similarity_value)
    return 1 if similarity_value>0.997 else 0

# %%
query = "they are afraid of people. people are not good."
gen_grammar_check(query)
# Out:
# input query: they are afraid of people. people are not good.
# generated correction: they are afraid of people. people are not good.
# [[1.]]
# 1

# %%
#load test data
df = pd.read_csv("grammar_test.csv", delimiter=',', header=None, names=['sentence', 'label'])
df.head()
# Out:
#                                             sentence  label
# 0               We ate at a really fancy restaurant.      1
# 1               John was unknown to be the murderer.      0
# 2  On which I consulted with the chairman of the ...      0
# 3                       David constructed the house.      1
# 4           He'll bring me a hot dog if he sees one.      1

# %%
df['preds'] = df['sentence'][:100].apply(lambda x: gen_grammar_check(x))
# Out:
# input query: we ate at a really fancy restaurant.
# generated correction: we ate at a really fancy restaurant.
# [[1.]]
# input query: john was unknown to be the murderer.
# generated correction: john was unknown to be the murderer.
# [[1.]]
# input query: on which i consulted with the chairman of the select committee was this matter.
# generated correction: on which i consulted with the chairman of the select committee was this matter.
# [[1.]]
# input query: david constructed the house.
# generated correction: david constructed the house.
# [[1.]]
# input query: he'll bring me a hot dog if he sees one.
# generated correction: he'll bring me a hot dog if he sees one.
# [[1.]]
# input query: a boy did not laugh.
# generated correction: a boy did not laugh.
# [[1.]]
# input query: i admired him a teacher.
# generated correction: i admired him as a teacher.
# [[0.9795603]]
# input query: henry wanted to possibly marry fanny.
# generated correction: henry wanted to possibly marry fanny.
# [[1.]]
# input query: the imposition of the government of a fine.
# generated correction: the imposition of a fine by the government.
# [[0.96644899]]
# input query: bill reading of shakespeare satisfied me
# generated correction: bill's reading of shakespeare satisfied me.
# [[0.93507521]]
# input query: who did you think mary saw?
# generated correction: who did you think mary saw?
# [[1.]]
# input query: the volcano erupts on tuesday.
# generated correction: the volcano erupted on tuesday.
# [[0.8619667]]
# input query: john convinced it to be raining.
# generated correction: john convinced me that it was raining.
# [[0.9416435]]
# input query: of bill on, this girl in the red coat will put a picture of bill on your desk before tomorrow.
# generated correction: of bill on, this girl in the red coat will put a picture of bill on your desk before tomorrow.
# [[1.]]
# input query: water fills the tub.
# generated correction: water fills the tub.
# [[1.]]
# input query: we listened to as little of his speech as possible.
# generated correction: we listened to as little of his speech as possible.
# [[1.]]
# input query: the socks are ready for you to announce that you will put them on.
# generated correction: the socks are ready for you to announce that you will put them on.
# [[1.]]
# input query: packages drive easily.
# generated correction: packages drive easily.
# [[1.]]
# input query: the cup filled water.
# generated correction: the cup filled with water.
# [[0.94689051]]
# input query: this dough shapes a good loaf.
# generated correction: this dough shapes a good loaf.
# [[1.]]
# input query: the man chased fido returned.
# generated correction: the man chased fido home.
# [[0.92904605]]
# input query: the ferrari which pietro bought from me and sofia adores him cost him a bundle.
# generated correction: the ferrari which pietro bought from me and sofia adores him cost him a bundle.
# [[1.]]
# input query: kim must baked a cake.
# generated correction: kim must have baked a cake.
# [[0.93306336]]
# input query: the magician vanished a rabbit into thin air.
# generated correction: the magician vanished a rabbit into thin air.
# [[1.]]
# input query: kevin ate spaghetti with a spoon and geordie did so too.
# generated correction: kevin ate spaghetti with a spoon, and geordie did so, too.
# [[0.9937129]]
# input query: john wants him to leave.
# generated correction: john wants him to leave.
# [[1.]]
# input query: there were killed three men by the assassin.
# generated correction: there were killed three men by the assassin.
# [[1.]]
# input query: the cattle herded.
# generated correction: the cattle herded.
# [[1.]]
# input query: clouds cleared from the sky.
# generated correction: clouds cleared from the sky.
# [[1.]]
# input query: they gave my father, who had just turned 60, it.
# generated correction: they gave my father, who had just turned 60, a ticket.
# [[0.79069269]]
# input query: i put the books on the table.
# generated correction: i put the books on the table.
# [[1.]]
# input query: fred offered the ball over molly.
# generated correction: fred offered the ball to molly.
# [[0.95107853]]
# input query: i didn't eat the ice cream and any cake.
# generated correction: i didn't eat the ice cream or any cake.
# [[0.96821485]]
# input query: i do not have sung.
# generated correction: i do not have sung.
# [[1.]]
# input query: i gave a picture of a covered bridge and to my sister a hundred hikers from hoboken.
# generated correction: i gave a picture of a covered bridge to my sister and a hundred hikers from hoboken.
# [[0.97510069]]
# input query: we yelled ourselves.
# generated correction: we yelled ourselves hoarse.
# [[0.87601641]]
# input query: paula spanked her right hand against the naughty child.
# generated correction: paula spanked her right hand against the naughty child.
# [[1.]]
# input query: the eggs mixed with the cream.
# generated correction: the eggs were mixed with the cream.
# [[0.93040369]]
# input query: norman lemming jumped off the cliff and william lemming did so too.
# generated correction: norman lemming jumped off the cliff, and william lemming did so too.
# [[0.99657993]]
# input query: the higher the stakes, the lower his expectations.
# generated correction: the higher the stakes, the lower his expectations were.
# [[0.92050064]]
# input query: we, we'll go together.
# generated correction: we will go together.
# [[0.92471751]]
# input query: i inquired could we leave early.
# generated correction: i inquired whether we could leave early.
# [[0.97843437]]
# input query: if my father, he comes home late, my mother always grills him.
# generated correction: if my father came home late, my mother always grilled him.
# [[0.81004412]]
# input query: sam progressed.
# generated correction: sam progressed.
# [[1.]]
# input query: we gave any senator enough opportunity and, sure enough, he succumbed to corruption.
# generated correction: we gave any senator enough opportunity, and, sure enough, he succumbed to corruption.
# [[0.99770555]]
# input query: the drunk hugged the lamppost.
# generated correction: the drunk hugged the lamppost.
# [[1.]]
# input query: our paycheck contributed.
# generated correction: our paycheck contributed.
# [[1.]]
# input query: some of them made as many errors as joan.
# generated correction: some of them made as many errors as joan.
# [[1.]]
# input query: the kids have arrived safely.
# generated correction: the kids have arrived safely.
# [[1.]]
# input query: john mentioned the issue to me.
# generated correction: john mentioned the issue to me.
# [[1.]]
# input query: jack eats more caviar than he sleeps.
# generated correction: jack eats more caviar than he sleeps.
# [[1.]]
# input query: john put his gold.
# generated correction: john put his gold.
# [[1.]]
# input query: what did john wonder who would win?
# generated correction: what did john wonder who would win?
# [[1.]]
# input query: john kept behind the counter.
# generated correction: john kept behind the counter.
# [[1.]]
# input query: john's i stole bike.
# generated correction: john's bicycle was stolen.
# [[0.86223531]]
# input query: whether he left!
# generated correction: whether he left!
# [[1.]]
# input query: himself laughs.
# generated correction: himself laughs.
# [[1.]]
# input query: calvin not will eat the beef waffles.
# generated correction: calvin will not eat the beef waffles.
# [[0.97745557]]
# input query: to which man did you talk to?
# generated correction: to which man did you talk to?
# [[1.]]
# input query: carla poured the pitcher with lemonade.
# generated correction: carla poured the pitcher of lemonade.
# [[0.99499679]]
# input query: the hardest that it ever snowed was last january 12th.
# generated correction: the hardest that it ever snowed was last january 12th.
# [[1.]]
# input query: there are only one chemical substance involved in nerve transmission.
# generated correction: there is only one chemical substance involved in nerve transmission.
# [[0.99584049]]
# input query: the joneses think themselves the best family on the block.
# generated correction: the joneses think they are the best family on the block.
# [[0.98434321]]
# input query: the more obnoxious fred, the less you should pay attention to him.
# generated correction: the more obnoxious fred is, the less you should pay attention to him.
# [[0.99429802]]
# input query: i believe that the problem is not easy to be obvious.
# generated correction: i believe that the problem is not easy to be obvious.
# [[1.]]
# input query: john put the book on the table.
# generated correction: john put the book on the table.
# [[1.]]
# input query: the car had a yellow collar on the dog which it injured.
# generated correction: the car had a yellow collar on the dog, which it injured.
# [[0.99685062]]
# input query: the brave are not afraid to die.
# generated correction: the brave are not afraid to die.
# [[1.]]
# input query: john destroyed the house.
# generated correction: john destroyed the house.
# [[1.]]
# input query: i ate sugar.
# generated correction: i ate sugar.
# [[1.]]
# input query: gilgamesh loved ishtar and aphrodite did too
# generated correction: gilgamesh loved ishtar, and aphrodite did too.
# [[0.98384315]]
# input query: golfer who is in training has a pretty powerful swing.
# generated correction: a golfer in training has a pretty powerful swing.
# [[0.94017977]]
# input query: he hit the ball.
# generated correction: he hit the ball.
# [[1.]]
# input query: ellen said something.
# generated correction: ellen said something.
# [[1.]]
# input query: julie became a fond of lloyd.
# generated correction: julie became fond of lloyd.
# [[0.97848307]]
# input query: i want jean to dance.
# generated correction: i want jean to dance.
# [[1.]]
# input query: kim depends at sandy.
# generated correction: kim depends on sandy.
# [[0.9394108]]
# input query: sam stood near yesterday every one of the women we'd been discussing.
# generated correction: sam stood near yesterday all of the women we'd been discussing.
# [[0.97335434]]
# input query: willy is taller than i know a boy who is.
# generated correction: willy is taller than i know a boy who is.
# [[1.]]
# input query: i ask you if this is what you want.
# generated correction: i ask you if this is what you want.
# [[1.]]
# input query: mickey looked the reference up.
# generated correction: mickey looked up the reference.
# [[0.94872197]]
# input query: robert knows that it is essential to be well behaved.
# generated correction: robert knows that it is essential to be well-behaved.
# [[0.99119574]]
# input query: look after herself!
# generated correction: look after herself!
# [[1.]]
# input query: no one expected to win.
# generated correction: no one expected to win.
# [[1.]]
# input query: john stayed kim behind the garage.
# generated correction: john stayed behind the garage.
# [[0.92377353]]
# input query: i know which book mag read, and which book bob asked why you hadn't.
# generated correction: i know which book maggie read, and which book bob asked why you hadn't.
# [[0.92568802]]
# input query: frances hid sally of the presents.
# generated correction: frances hid sally's present of the presents.
# [[0.96840537]]
# input query: john saw anything.
# generated correction: john saw anything.
# [[1.]]
# input query: he is the happiest that it is believed that he has ever been.
# generated correction: he is the happiest that he has ever been.
# [[0.95129826]]
# input query: we gave him enough opportunity and, sure enough, every senator succumbed to corruption.
# generated correction: we gave him enough opportunity and, sure enough, every senator succumbed to corruption.
# [[1.]]
# input query: can you find the light bulb store?
# generated correction: can you find the light bulb store?
# [[1.]]
# input query: he will have been seeing his children.
# generated correction: he will have been seeing his children.
# [[1.]]
# input query: here's a razor for you to chop up these nuts with this cleaver and.
# generated correction: here's a razor for you to chop up these nuts with this cleaver.
# [[0.99685848]]
# input query: i inquired for john to like his beer.
# generated correction: i inquired of john whether he liked his beer.
# [[0.9458533]]
# input query: john eats more than he sleeps.
# generated correction: john eats more than he sleeps.
# [[1.]]
# input query: they heard john's criticism of themselves.
# generated correction: they heard john's criticism of themselves.
# [[1.]]
# input query: he never achieved anything, did he?
# generated correction: he never achieved anything, did he?
# [[1.]]
# input query: the more he reads, the more books i wonder to whom he will give.
# generated correction: the more he reads, the more books i wonder to whom he will give.
# [[1.]]
# input query: any pilot on duty today must be flying this plane.
# generated correction: any pilot on duty today must fly this plane.
# [[0.95184525]]
# input query: that the cops spoke to the janitor about it yesterday, that robbery, is terrible.
# generated correction: that the cops spoke to the janitor about it yesterday is terrible.
# [[0.86500349]]

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
labels = df['label'][:100].astype(float).to_list()
preds = df['preds'][:100].to_list()

print(f'accuracy = {accuracy_score(labels, preds)}')
print(f'precision = {precision_score(labels, preds, pos_label=0)}')
print(f'recall = {recall_score(labels, preds, pos_label=0)}')
# Out:
# accuracy = 0.59
# precision = 0.7368421052631579
# recall = 0.4745762711864407

# %% [markdown]
# next

# %%
#load test data
df = pd.read_csv("grammar_test.csv", delimiter=',', header=None, names=['sentence', 'label'])
df.head()

# %%
import time
def class_grammar_check(query):
    response = co.classify(
    model='cdb39157-6b82-4cb4-92c5-9e6037623d79-ft',
    inputs=[f"{query}"])
    # print(response.classifications[0].prediction)
    time.sleep(1) # beacause of 100 calls/min limit on trial key from Cohere
    return(float(response.classifications[0].prediction))

# %%
query = "they are afraid of people. people are not good."
class_grammar_check(query)
# Out:
# 1.0

# %%
df['preds'] = df['sentence'][:1000].apply(lambda x: class_grammar_check(x))

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
labels = df['label'][:1000].astype(float).to_list()
preds = df['preds'][:1000].to_list()

print(f'accuracy = {accuracy_score(labels, preds)}')
print(f'precision = {precision_score(labels, preds, pos_label=0)}')
print(f'recall = {recall_score(labels, preds, pos_label=0)}')
# Out:
# accuracy = 0.676
# precision = 0.8928571428571429
# recall = 0.4
